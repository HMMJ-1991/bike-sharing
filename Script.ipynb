# %%
import numpy as np
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from nltk.probability import FreqDist
import seaborn as sns
#sns.set(style"ticks", color_codes=True)

dataset = pd.read_csv('data/201912-capitalbikeshare-tripdata.csv')
#print(dataset.head())

dataset['Member type'].value_counts().plot(kind='bar')
