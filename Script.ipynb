# %%
import numpy as np
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from nltk.probability import FreqDist
import seaborn as sns
sns.set_style("dark")

df = pd.read_csv('data/201912-capitalbikeshare-tripdata.csv')
#print(dataset.head())

# %%
# plot and save with seaborn
sns.set_style("dark")
countplot = sns.countplot(x="Member type", data=df);

fig = countplot.get_figure()
fig.savefig('Figures/member type.png')
